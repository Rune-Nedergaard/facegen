# %%
import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

folder = "subset_300_white_men_20_35"

images = []
image_names = []

for filename in os.listdir(folder):
    if filename.lower().endswith((".png", ".jpg", ".jpeg")):
        path = os.path.join(folder, filename)

        img = Image.open(path).convert("L")
        img = np.array(img, dtype=float)

        images.append(img)
        image_names.append(filename)

images = np.array(images)

mean_image = np.mean(images, axis=0)

print("Number of images:", len(images))
print("Image shape:", mean_image.shape)

plt.imshow(mean_image, cmap="gray")
plt.axis("off")
plt.title("Mean Image")
plt.show()
# Out:
# Number of images: 278
# Image shape: (64, 64)

# %%
from sklearn.decomposition import PCA

centered_images = images - mean_image

n_images, height, width = centered_images.shape
X = centered_images.reshape(n_images, height * width)

pca = PCA()
X_pca = pca.fit_transform(X)

print("PCA shape:", X_pca.shape)
# Out:
# PCA shape: (278, 278)

# %%
cumulative_variance = np.cumsum(pca.explained_variance_ratio_)

n_components = np.argmax(cumulative_variance >= 0.95) + 1

print(n_components)
# Out:
# 87

# %%
first_5 = pca.explained_variance_ratio_[:5]

print("Explained variance by first 5 PCs:")
for i, value in enumerate(first_5, start=1):
    print(f"PC{i}: {value * 100:.2f}%")

print(f"Total explained by first 5 PCs: {first_5.sum() * 100:.2f}%")
# Out:
# Explained variance by first 5 PCs:
# PC1: 23.50%
# PC2: 15.53%
# PC3: 10.93%
# PC4: 5.68%
# PC5: 4.18%
# Total explained by first 5 PCs: 59.83%

# %%
fig, axes = plt.subplots(1, 20, figsize=(15, 3))

for i in range(20):
    pc_image = pca.components_[i].reshape(height, width)
    axes[i].imshow(pc_image, cmap="gray")
    axes[i].set_title(f"PC {i+1}")
    axes[i].axis("off")

plt.tight_layout()
plt.show()

# %%
pc_index = 0  # 0 = PC1, 1 = PC2, etc.

pc = pca.components_[pc_index].reshape(height, width)
scores = X_pca[:, pc_index]

min_score = np.min(scores)
max_score = np.max(scores)

img_min = mean_image + min_score * pc
img_mean = mean_image
img_max = mean_image + max_score * pc

fig, axes = plt.subplots(1, 3, figsize=(12, 4))

axes[0].imshow(img_min, cmap="gray")
axes[0].set_title(f"Mean + min score * PC{pc_index+1}")
axes[0].axis("off")

axes[1].imshow(img_mean, cmap="gray")
axes[1].set_title("Mean image")
axes[1].axis("off")

axes[2].imshow(img_max, cmap="gray")
axes[2].set_title(f"Mean + max score * PC{pc_index+1}")
axes[2].axis("off")

plt.tight_layout()
plt.show()

# %%
import pandas as pd

df = pd.read_csv("s254232.csv")

images = pd.concat([df["Image"], df["Image"]], ignore_index=True)
ratings = pd.concat([df["Rating 1"], df["Rating 2"]], ignore_index=True)

new_df = pd.DataFrame({
    "Image": images,
    "Rating": ratings
})

# %%
import numpy as np
import pandas as pd
from sklearn.feature_selection import SequentialFeatureSelector
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GroupKFold

# Only keep the first PCs explaining at least 95%
X_selected = X_pca[:, :n_components]

# PCA scores + corresponding image names
pc_df = pd.DataFrame(X_selected)
pc_df["Image"] = image_names

# Put Rating 1 and Rating 2 underneath each other
ratings_df = pd.DataFrame({
    "Image": pd.concat([df["Image"], df["Image"]], ignore_index=True),
    "Rating": pd.concat([df["Rating 1"], df["Rating 2"]], ignore_index=True)
})

# Match ratings to the correct PCA image
data = ratings_df.merge(pc_df, on="Image")

# Remove missing ratings
data = data.dropna(subset=["Rating"])

# Make X, y and groups
X = data.drop(columns=["Image", "Rating"]).to_numpy()
y = data["Rating"].to_numpy()
groups = data["Image"].to_numpy()

print("X:", X.shape)
print("y:", y.shape)
# Out:
# X: (539, 87)
# y: (539,)

# %%
previous_selected = set()
selection_order = []

previous_score = -np.inf
best_selected = None

for k in range(1, n_components + 1):

    sfs = SequentialFeatureSelector(
        model,
        n_features_to_select=k,
        direction="forward",
        scoring="r2",
        cv=cv_splits
    )

    sfs.fit(X, y)

    selected = np.where(sfs.get_support())[0]
    selected_set = set(selected)

    # Find which PC was newly added
    new_pc = list(selected_set - previous_selected)[0]
    selection_order.append(new_pc + 1)

    score = cross_val_score(
        model,
        X[:, selected],
        y,
        cv=cv_splits,
        scoring="r2"
    ).mean()

    change = score - previous_score

    print(
        f"{k} PCs: {selection_order}   "
        f"R² = {score:.4f}   "
        f"Change = {change:+.4f}"
    )

    if score <= previous_score:
        print("\nNo improvement. Stopping.")
        selection_order.pop()  # remove the PC that made it worse
        break

    previous_score = score
    previous_selected = selected_set
    best_selected = selected.copy()

print("\nPCs picked in order:", selection_order)
print("Best CV R²:", round(previous_score, 4))
# Out:
# 1 PCs: [7]   R² = -0.0093   Change = +inf
# 2 PCs: [7, 58]   R² = 0.0160   Change = +0.0253
# 3 PCs: [7, 58, 45]   R² = 0.0344   Change = +0.0184
# 4 PCs: [7, 58, 45, 6]   R² = 0.0534   Change = +0.0190
# 5 PCs: [7, 58, 45, 6, 11]   R² = 0.0696   Change = +0.0162
# 6 PCs: [7, 58, 45, 6, 11, 2]   R² = 0.0855   Change = +0.0159
# 7 PCs: [7, 58, 45, 6, 11, 2, 5]   R² = 0.1026   Change = +0.0171
# 8 PCs: [7, 58, 45, 6, 11, 2, 5, 10]   R² = 0.1197   Change = +0.0170
# 9 PCs: [7, 58, 45, 6, 11, 2, 5, 10, 8]   R² = 0.1299   Change = +0.0103
# 10 PCs: [7, 58, 45, 6, 11, 2, 5, 10, 8, 76]   R² = 0.1402   Change = +0.0102
# 11 PCs: [7, 58, 45, 6, 11, 2, 5, 10, 8, 76, 39]   R² = 0.1506   Change = +0.0105
# 12 PCs: [7, 58, 45, 6, 11, 2, 5, 10, 8, 76, 39, 55]   R² = 0.1612   Change = +0.0106
# 13 PCs: [7, 58, 45, 6, 11, 2, 5, 10, 8, 76, 39, 55, 53]   R² = 0.1702   Change = +0.0090
# 14 PCs: [7, 58, 45, 6, 11, 2, 5, 10, 8, 76, 39, 55, 53, 20]   R² = 0.1773   Change = +0.0071
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Fit final regression model using the selected PCs
X_model = X[:, best_selected]
model = LinearRegression()
model.fit(X_model, y)

beta0 = model.intercept_
beta = model.coef_

def synthetic_face(target_rating):
    # Smallest PC-score vector that gives the target rating
    z = ((target_rating - beta0) / np.sum(beta**2)) * beta

    # Reconstruct image from mean + weighted selected PCs
    face_vec = mean_image.ravel() + z @ pca.components_[best_selected, :]
    face_img = face_vec.reshape(height, width)

    # Clip to valid grayscale range
    face_img = np.clip(face_img, 0, 255)

    return face_img

# If your ratings are 1,2,3,4,5, these are the natural targets:
target_ratings = [0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5]

# If your assignment literally wants 11 faces and repeats 5, use this instead:
# target_ratings = [1, 2, 3, 4, 5, 0.5, 1.5, 2.5, 3.5, 4.5, 5]

faces = [synthetic_face(r) for r in target_ratings]

fig, axes = plt.subplots(2, 5, figsize=(15, 6))

for ax, r, face in zip(axes.ravel(), target_ratings, faces):
    ax.imshow(face, cmap="gray")
    ax.set_title(f"Rating {r}")
    ax.axis("off")

plt.tight_layout()
plt.show()
